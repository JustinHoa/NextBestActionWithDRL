# %%
import pandas as pd
import os

# %%
print(os.getcwd())
# Out:
# d:\Bachelor_Thesis\Code\NextBestActionWithRL\data\preprocess_data\general_check_up

# %%
q_table = pd.read_csv("q_table.csv")

# %%
q_table.head()
# Out:
#                                               prefix   Payment  \
# 0                                  ('Registration',)  5.857017
# 1                        ('Registration', 'Payment')  0.000000
# 2   ('Registration', 'Payment', 'Get Triage Number')  0.000000
# 3  ('Registration', 'Payment', 'Get Triage Number...  0.000000
# 4  ('Registration', 'Payment', 'Get Triage Number...  0.000000
#
#    Get Triage Number  Measure Vital Signs  General Medicine Examination  \
# 0           0.000000             0.000000                      0.000000
# 1           5.455189             0.000000                      0.000000
# 2           0.000000             4.991463                      0.000000
# 3           0.000000             0.000000                      4.752676
# 4           0.000000             0.000000                      0.000000
#
#    Eye Examination  Dental Examination  Chest X-ray  Cardiac Ultrasound  \
# 0         0.000000            0.000000      0.00000            0.000000
# ...
