# %%
import d3rlpy

dataset, env = d3rlpy.datasets.get_dataset("hopper-medium-v0")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\d3rlpy\datasets.py:418, in get_d4rl(env_name, transition_picker, trajectory_slicer, render_mode, max_episode_steps)
#     417 try:
# --> 418     import d4rl  # noqa
#     419     from d4rl.pointmaze.maze_model import MazeEnv
#
# ModuleNotFoundError: No module named 'd4rl'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 import d3rlpy
# ----> 3 dataset, env = d3rlpy.datasets.get_dataset("hopper-medium-v0")
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\d3rlpy\datasets.py:734, in get_dataset(env_name, transition_picker, trajectory_slicer, render_mode)
#     727     return get_d4rl(
# ...
